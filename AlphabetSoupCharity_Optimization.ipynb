# %% [markdown]
# Data Loading and Preprocessing (Copied from Starter_Code.ipynb)

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(columns=["EIN", "NAME"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_value_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_value_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Use a cutoff value of 150 (instead of 200 in the non-optimized model) applications and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = []
for app in list(application_type_value_counts.index):
  if application_type_value_counts[app]<15:
    application_types_to_replace.append(app)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_value_counts = application_df["CLASSIFICATION"].value_counts()
for i in classification_value_counts.index:
  print(i, classification_value_counts[i])
# Out:
# C1000 17326
# C2000 6074
# C1200 4837
# C3000 1918
# C2100 1883
# C7000 777
# C1700 287
# C4000 194
# C5000 116
# C1270 114
# C2700 104
# C2800 95
# C7100 75
# C1300 58
# C1280 50
# C1230 36
# C1400 34
# C7200 32
# C2300 32
# C1240 30
# C8000 20
# C7120 18
# C1500 16
# C1800 15
# C6000 15
# C1250 14
# C8200 11
# C1238 10
# C1278 10
# C1235 9
# C1237 9
# C7210 7
# C2400 6
# C1720 6
# C4100 6
# C1257 5
# C1600 5
# C1260 3
# C2710 3
# C0 3
# C3200 2
# C1234 2
# C1246 2
# C1267 2
# C1256 2
# C2190 1
# C4200 1
# C2600 1
# C5200 1
# C1370 1
# C1248 1
# C6100 1
# C1820 1
# C1900 1
# C1236 1
# C3700 1
# C2570 1
# C1580 1
# C1245 1
# C2500 1
# C1570 1
# C1283 1
# C2380 1
# C1732 1
# C1728 1
# C2170 1
# C4120 1
# C8210 1
# C2561 1
# C4500 1
# C2150 1

# %%
# Use a cutoff value of 50 (instead of 1000 in non-optimized)
# and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = []
for c in list(classification_value_counts.index):
  if classification_value_counts[c]<50:
    classifications_to_replace.append(c)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      391
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0                     1                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T2  APPLICATION_TYPE_T3  ...  \
# 0                     0                    0                    0  ...
# ...

# %% [markdown]
# Standardize the Ask Amount Column

# %%
from sklearn.preprocessing import StandardScaler

# %%
#StandardScale the ASK_AMT column
application_df["ASK_AMT"] = StandardScaler().fit_transform(application_df[["ASK_AMT"]])

#show the updated df
application_df.head()
# Out:
#    STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1 -0.031725              1                       0
# 1       1 -0.030536              1                       0
# 2       1 -0.031725              0                       0
# 3       1 -0.031706              1                       0
# 4       1 -0.030146              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0                     1                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T2  APPLICATION_TYPE_T3  ...  \
# 0                     0                    0                    0  ...
# ...

# %% [markdown]
# Implementation of Deep Neural Network

# %%
# Split our preprocessed data into our features (PCA columns) and target arrays
y = application_df["IS_SUCCESSFUL"]
X = application_df.drop("IS_SUCCESSFUL",axis=1)

# Split the preprocessed data into a training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# Model Optimization - Using Keras-Tuner

# %%
pip install -q keras-tuner
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 4.2 MB/s eta 0:00:00

# %%
X_train.head()
# Out:
#        STATUS   ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 10679       1 -0.031725                       0                     0
# 5052        1 -0.031725                       0                     0
# 9990        1 -0.031725                       0                     0
# 25173       1 -0.031725                       0                     0
# 11405       1 -0.031725                       0                     1
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  \
# 10679                     0                     0                     0
# 5052                      0                     0                     0
# 9990                      0                     0                     0
# 25173                     0                     0                     0
# 11405                     0                     0                     0
#
#        APPLICATION_TYPE_T2  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  ...  \
# ...

# %%
#make a function that will create a single sequential model with hyperparameter options
#options include - choices of activation functions between layers, numbers of neurons, and
#the number of layers

#After running the optimizer with 1-4 layers, 3 layers was selected for subsequent attempts

def makeModel(hp): #hyperparameters that will be passed in from a Hyperband tuner variabl

  #set up the sequential model
  nnModel = tf.keras.models.Sequential()

  #set up choices for the activation funcitons to be used in the hidden layers
  activationList = hp.Choice('activation', ['relu','tanh'])

  #set up the keras tuner to decide (loop) through a number of attributes in the first layer
  # - input_dim =57
  # - loop through 50-60 neurons on the first hidden layer
  nnModel.add(
      tf.keras.layers.Dense(
          input_dim=57,
          activation=activationList,
          units=hp.Int('first_units', min_value=50, max_value=60)
      )
  )

  #add the hidden layers with neurons on each layer
  nnModel.add(
       tf.keras.layers.Dense(
           activation=activationList,
           units = hp.Int('units_0', min_value=35, max_value=40)
       )
   )


  nnModel.add(
       tf.keras.layers.Dense(
           activation=activationList,
           units = hp.Int('units_1', min_value=10, max_value=15)
       )
   )


  nnModel.add(
       tf.keras.layers.Dense(
           activation=activationList,
           units = hp.Int('units_2', min_value=4, max_value=6)
       )
   )

  #set up the output layer (1 node)
  nnModel.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

  #compile the model
  nnModel.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  return nnModel

# %%
#import the keras-tuner modules
import keras_tuner as kt

# %%
#use the Hyperband function in order to run the optimizer function

ktModel = kt.Hyperband(
    #pass in the function that contains the attributes
    makeModel,
    #pass in the val_accuracy objective function
    objective= 'val_accuracy',
    #tell the max_epochs
    max_epochs=30,
    #tell the number of hyperband iterations
    hyperband_iterations=2
)

# %%
#use the .serach() from keras tuner to search for the best combo hyperparameters
ktModel.search(X_train, y_train, epochs=30, validation_data=[X_test, y_test])
# Out:
# Trial 180 Complete [00h 01m 24s]
# val_accuracy: 0.7329446077346802
#
# Best val_accuracy So Far: 0.734810471534729
# Total elapsed time: 01h 08m 59s

# %%
#get best hyper parameters
ktModel.get_best_hyperparameters(1)[0].values
# Out:
# {'activation': 'relu',
#  'first_units': 59,
#  'units_0': 36,
#  'units_1': 14,
#  'units_2': 4,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 1,
#  'tuner/round': 0}

# %%
#store the model
bestDLModel = ktModel.get_best_models(1)[0]

#evaluate the model
bestDLModel_loss, bestDLModel_accuracy = bestDLModel.evaluate(X_test, y_test)
# Out:
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5478 - accuracy: 0.7348

# %% [markdown]
# Run with additional Epochs

# %%
#Recreate BestDLModel

#set up the sequential model
nnModel = tf.keras.models.Sequential()

# First Layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=57, units = 59, activation='relu')
)

# First hidden layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=59, units = 36, activation='relu')
)

# Second hidden layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=36, units = 14, activation='relu')
)

# Third hidden layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=14, units = 4, activation='relu')
)

# Output layer - don't need to put inputs on final layer
# Only need 1 unit (IS_SUCCESSFUL) and use activation function of sigmoid
nnModel.add(
    tf.keras.layers.Dense(units = 1, activation='sigmoid')
)

# Check the structure of the model
nnModel.summary()

#compile the model
nnModel.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 59)                3422
#
#  dense_6 (Dense)             (None, 36)                2160
#
#  dense_7 (Dense)             (None, 14)                518
#
#  dense_8 (Dense)             (None, 4)                 60
#
#  dense_9 (Dense)             (None, 1)                 5
#
# ...
# Total params: 6,165
# Trainable params: 6,165
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
fitModel = nnModel.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5738 - accuracy: 0.7196
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7298
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7317
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7324
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7332
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7340
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7346
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5414 - accuracy: 0.7357
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7368
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nnModel.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5749 - accuracy: 0.7298 - 468ms/epoch - 2ms/step
# Loss: 0.5748953223228455, Accuracy: 0.7297959327697754

# %%
# Export our model to HDF5 file
nnModel.save('AlphabetSoupCharity_Optimization.h5')
